# %%
import spacy

nlp = spacy.load("zh_core_web_md")
doc = nlp("今天天气不错，挺风和日丽的，我们下午没有课。")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\Lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 1.049 seconds.
# Prefix dict has been built succesfully.
# 今天 今天 NOUN NT nmod:tmod xx True True
# 天气 天气 NOUN NN nsubj xx True False
# 不错 不错 VERB VA ROOT xx True False
# ， ， PUNCT PU punct ， False True
# 挺 挺 ADV AD advmod x True False
# 风和日丽 风和日丽 VERB VA conj xxxx True False
# 的 的 PART SP discourse x True True
# ， ， PUNCT PU punct ， False True
# 我们 我们 PRON PN nsubj xx True True
# 下午 下午 NOUN NT nmod:tmod xx True False
# 没有 没有 VERB VE conj xx True True
# 课 课 NOUN NN dobj x True False
# 。 。 PUNCT PU punct 。 False True

# %%
from spacy import displacy
html = displacy.render(doc, style="dep",options = {'distance':105})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="zh" id="34545bb604994de6972399f4c4995a42-0" class="displacy" width="1100" height="294.5" direction="ltr" style="max-width: none; height: 294.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">今天</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="155">天气</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="155">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="260">不错，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="260">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="365">挺</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="365">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="470">风和日丽</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="470">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">的，</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="680">我们</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="785">下午</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="785">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="890">没有</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="204.5">
#     <tspan class="displacy-word" fill="currentColor" x="995">课。</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="995">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-0" stroke-width="2px" d="M70,159.5 C70,54.5 255.0,54.5 255.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:tmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,161.5 L62,149.5 78,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-1" stroke-width="2px" d="M175,159.5 C175,107.0 250.0,107.0 250.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M175,161.5 L167,149.5 183,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-2" stroke-width="2px" d="M385,159.5 C385,107.0 460.0,107.0 460.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M385,161.5 L377,149.5 393,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-3" stroke-width="2px" d="M280,159.5 C280,54.5 465.0,54.5 465.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M465.0,161.5 L473.0,149.5 457.0,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-4" stroke-width="2px" d="M490,159.5 C490,107.0 565.0,107.0 565.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">discourse</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,161.5 L573.0,149.5 557.0,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-5" stroke-width="2px" d="M700,159.5 C700,54.5 885.0,54.5 885.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M700,161.5 L692,149.5 708,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-6" stroke-width="2px" d="M805,159.5 C805,107.0 880.0,107.0 880.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod:tmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M805,161.5 L797,149.5 813,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-7" stroke-width="2px" d="M280,159.5 C280,2.0 890.0,2.0 890.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M890.0,161.5 L898.0,149.5 882.0,149.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-34545bb604994de6972399f4c4995a42-0-8" stroke-width="2px" d="M910,159.5 C910,107.0 985.0,107.0 985.0,159.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-34545bb604994de6972399f4c4995a42-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M985.0,161.5 L993.0,149.5 977.0,149.5" fill="currentColo
