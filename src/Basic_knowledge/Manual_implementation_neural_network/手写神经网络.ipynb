# %% [markdown]
# ![%E5%9F%BA%E6%9C%AC%E6%84%9F%E7%9F%A5%E5%99%A8.jpg](attachment:%E5%9F%BA%E6%9C%AC%E6%84%9F%E7%9F%A5%E5%99%A8.jpg)
#
# 工作流程：
#
# 神经元（Neuron）收到输入x，输入x和权重w相乘后叠加合并形成网络输入；网络输入被传送到激活函数，生成输出（Output，1 或 0） 。如果在训练阶段，则输出将被用于和真实输出进行误差计算，并依此更新权重w
#
# 感知器为神经元的工作方式，神经网络是多个感知器的集合。
